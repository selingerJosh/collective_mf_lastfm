# %%
import pandas as pd
import matplotlib.pyplot as plt


df_user_artist = pd.read_csv("data/user_artists.dat", sep = '\\t', engine='python')

df_artist = pd.read_csv("data/artists.dat", sep = '\\t', engine='python')

# %%
test = pd.DataFrame({'a':[1,2,3,4], 'b':[2,5,7,9]})

test.plot()
plt.show()
